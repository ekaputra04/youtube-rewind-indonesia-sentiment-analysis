# %% [markdown]
# # Cleansing Data Youtube Rewind 2020

# %% [markdown]
# #### Import Library

# %%
from dotenv import load_dotenv
from pymongo import MongoClient
import os
import pandas as pd

# %% [markdown]
# #### Import url dari .env

# %%
# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
database_name = "youtube_rewind_indonesia"
collection_from = "collect_2020"
collection_name = "cleansing_2020"

# %% [markdown]
# #### Import dataset dari MongoDB

# %%
# Koneksi ke MongoDB
client = MongoClient(local_url)

# Pilih database dan koleksi
db = client[database_name]
collection = db[collection_from]

# Query data dari koleksi
cursor = collection.find()

# Konversi cursor ke list dan kemudian ke DataFrame
data = list(cursor)
df = pd.DataFrame(data)

# Menutup koneksi
client.close()

# %%
df
# Out:
#                              _id                 channelId      videoId  \
# 0       66516226b0b542363152a0f6  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 1       66516226b0b542363152a0f7  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 2       66516226b0b542363152a0f8  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 3       66516226b0b542363152a0f9  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 4       66516226b0b542363152a0fa  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# ...                          ...                       ...          ...
# 333495  665165f5b0b542363157b7ad  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333496  665165f5b0b542363157b7ae  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333497  665165f5b0b542363157b7af  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333498  665165f5b0b542363157b7b0  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333499  665165f5b0b542363157b7b1  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
#
#                                               textDisplay  \
# 0       We, from the Rewind Indonesia 2020 team respec...
# 1                                                 Afa ada
# 2                                                   ❤❤❤❤❤
# 3                                          Gw kangen 2020
# 4        Kerja bagus ini sunggnh bagus woh semoga di baca
# ...                                                   ...
# 333495  <a href="https://www.youtube.com/watch?v=LhYfs...
# 333496                             WOII KEREN BANGEETTTTT
# 333497                             Masih best rewind 2018
# 333498  The epic moments <a href="http://www.youtube.c...
# 333499                      merinding banget sumpah 😔❤❤❤❤
#
#                                              textOriginal  \
# 0       We, from the Rewind Indonesia 2020 team respec...
# 1                                                 Afa ada
# 2                                                   ❤❤❤❤❤
# 3                                          Gw kangen 2020
# 4        Kerja bagus ini sunggnh bagus woh semoga di baca
# ...                                                   ...
# 333495                                    6:40 merinding😶
# 333496                             WOII KEREN BANGEETTTTT
# 333497                             Masih best rewind 2018
# 333498                           The epic moments #RI2020
# 333499                      merinding banget sumpah 😔❤❤❤❤
#
#                authorDisplayName  \
# 0             @IndonesianCreator
# 1          @muhammadfahryzal3498
# 2              @juliaazzahra7753
# 3               @user-bw3ze4hc8s
# 4               @user-ex8yk7tp1b
# ...                          ...
# 333495      @ismanoerfatah._1565
# 333496  @rahmafitriyanixotkp3148
# 333497       @ferzaexclusive6434
# 333498             @sulfadli2171
# 333499         @nadirasheril1886
#
#                                     authorProfileImageUrl  \
# 0       https://yt3.ggpht.com/fO77gm9qrRYfPRp2NDPodQ9i...
# 1       https://yt3.ggpht.com/ytc/AIdro_msn1kSAZwJIxjE...
# 2       https://yt3.ggpht.com/ytc/AIdro_kQOzuPqs3TbTAB...
# 3       https://yt3.ggpht.com/ytc/AIdro_nxHXmfTkoLg7t9...
# 4       https://yt3.ggpht.com/ytc/AIdro_nhfd1E23j6qheN...
# ...                                                   ...
# 333495  https://yt3.ggpht.com/ytc/AIdro_kGjodx108CD4Ay...
# 333496  https://yt3.ggpht.com/ytc/AIdro_kVt-2KnstlTCEK...
# 333497  https://yt3.ggpht.com/ytc/AIdro_nLVuCODvdNq-18...
# 333498  https://yt3.ggpht.com/hL8b3eYnmNVF3zxdio4XCk9D...
# 333499  https://yt3.ggpht.com/ytc/AIdro_kBJ6lXgh-zF7ee...
#
#                                        authorChannelUrl  \
# 0             http://www.youtube.com/@IndonesianCreator
# 1          http://www.youtube.com/@muhammadfahryzal3498
# 2              http://www.youtube.com/@juliaazzahra7753
# 3               http://www.youtube.com/@user-bw3ze4hc8s
# 4               http://www.youtube.com/@user-ex8yk7tp1b
# ...                                                 ...
# 333495      http://www.youtube.com/@ismanoerfatah._1565
# 333496  http://www.youtube.com/@rahmafitriyanixotkp3148
# 333497       http://www.youtube.com/@ferzaexclusive6434
# 333498             http://www.youtube.com/@sulfadli2171
# 333499         http://www.youtube.com/@nadirasheril1886
#
#                               authorChannelId  canRate viewerRating  \
# 0       {'value': 'UC-z1ubmS-iHMVr83EEwRS2g'}     True         none
# 1       {'value': 'UCWzMGAFOjdLfUWXivsxEI9Q'}     True         none
# 2       {'value': 'UCr1Ir_YJihU1cRgsmrnvPmQ'}     True         none
# 3       {'value': 'UC61igbTMzds0Qi91QQrMisg'}     True         none
# 4       {'value': 'UCwVWpc4IuZPjRM0qRySmLrA'}     True         none
# ...                                       ...      ...          ...
# 333495  {'value': 'UCMb4G1fBwvizjcnOVqrZr7A'}     True         none
# 333496  {'value': 'UCuulF5jlUYn8swz4ppweJ0A'}     True         none
# 333497  {'value': 'UCX-NYKe0VKw_VErNg5q594g'}     True         none
# 333498  {'value': 'UCldoMcS36F7yiYFQCtut8nQ'}     True         none
# 333499  {'value': 'UCcVzJlSjwjvrG9RO85P9vqg'}     True         none
#
#         likeCount           publishedAt             updatedAt
# 0           79203  2020-12-30T10:18:18Z  2021-01-25T08:51:33Z
# 1               0  2024-05-25T00:47:48Z  2024-05-25T00:47:48Z
# 2               0  2024-05-24T14:09:24Z  2024-05-24T14:09:24Z
# 3               1  2024-05-22T07:37:37Z  2024-05-22T07:37:37Z
# 4               0  2024-05-21T13:09:38Z  2024-05-21T13:09:38Z
# ...           ...                   ...                   ...
# 333495          0  2020-12-28T15:30:35Z  2020-12-28T15:30:35Z
# 333496          1  2020-12-28T15:30:35Z  2020-12-28T15:30:35Z
# 333497          0  2020-12-28T15:30:34Z  2020-12-28T15:33:59Z
# 333498          0  2020-12-28T15:30:34Z  2020-12-28T15:30:34Z
# 333499          0  2020-12-28T15:30:34Z  2020-12-28T15:30:34Z
#
# [333500 rows x 14 columns]

# %% [markdown]
# #### Menghapus data text yang duplikat

# %%
df = df.drop_duplicates(subset=['textOriginal'])

df.shape
# Out:
# (277039, 14)

# %% [markdown]
# #### Menghapus data author yang duplikat

# %%
df = df.drop_duplicates(subset=['authorChannelUrl'])

df.shape
# Out:
# (244034, 14)

# %% [markdown]
# #### Menghilangkan atribut yang tidak diperlukan

# %% [markdown]
# Karena hanya menganalisis komentar, maka atribut yang disisakan hanya _id dan textOriginal

# %%
# df = df[['_id', 'textOriginal']]
df
# Out:
#                              _id                 channelId      videoId  \
# 0       66516226b0b542363152a0f6  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 1       66516226b0b542363152a0f7  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 2       66516226b0b542363152a0f8  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 3       66516226b0b542363152a0f9  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 4       66516226b0b542363152a0fa  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# ...                          ...                       ...          ...
# 333495  665165f5b0b542363157b7ad  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333496  665165f5b0b542363157b7ae  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333497  665165f5b0b542363157b7af  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333498  665165f5b0b542363157b7b0  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 333499  665165f5b0b542363157b7b1  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
#
#                                               textDisplay  \
# 0       We, from the Rewind Indonesia 2020 team respec...
# 1                                                 Afa ada
# 2                                                   ❤❤❤❤❤
# 3                                          Gw kangen 2020
# 4        Kerja bagus ini sunggnh bagus woh semoga di baca
# ...                                                   ...
# 333495  <a href="https://www.youtube.com/watch?v=LhYfs...
# 333496                             WOII KEREN BANGEETTTTT
# 333497                             Masih best rewind 2018
# 333498  The epic moments <a href="http://www.youtube.c...
# 333499                      merinding banget sumpah 😔❤❤❤❤
#
#                                              textOriginal  \
# 0       We, from the Rewind Indonesia 2020 team respec...
# 1                                                 Afa ada
# 2                                                   ❤❤❤❤❤
# 3                                          Gw kangen 2020
# 4        Kerja bagus ini sunggnh bagus woh semoga di baca
# ...                                                   ...
# 333495                                    6:40 merinding😶
# 333496                             WOII KEREN BANGEETTTTT
# 333497                             Masih best rewind 2018
# 333498                           The epic moments #RI2020
# 333499                      merinding banget sumpah 😔❤❤❤❤
#
#                authorDisplayName  \
# 0             @IndonesianCreator
# 1          @muhammadfahryzal3498
# 2              @juliaazzahra7753
# 3               @user-bw3ze4hc8s
# 4               @user-ex8yk7tp1b
# ...                          ...
# 333495      @ismanoerfatah._1565
# 333496  @rahmafitriyanixotkp3148
# 333497       @ferzaexclusive6434
# 333498             @sulfadli2171
# 333499         @nadirasheril1886
#
#                                     authorProfileImageUrl  \
# 0       https://yt3.ggpht.com/fO77gm9qrRYfPRp2NDPodQ9i...
# 1       https://yt3.ggpht.com/ytc/AIdro_msn1kSAZwJIxjE...
# 2       https://yt3.ggpht.com/ytc/AIdro_kQOzuPqs3TbTAB...
# 3       https://yt3.ggpht.com/ytc/AIdro_nxHXmfTkoLg7t9...
# 4       https://yt3.ggpht.com/ytc/AIdro_nhfd1E23j6qheN...
# ...                                                   ...
# 333495  https://yt3.ggpht.com/ytc/AIdro_kGjodx108CD4Ay...
# 333496  https://yt3.ggpht.com/ytc/AIdro_kVt-2KnstlTCEK...
# 333497  https://yt3.ggpht.com/ytc/AIdro_nLVuCODvdNq-18...
# 333498  https://yt3.ggpht.com/hL8b3eYnmNVF3zxdio4XCk9D...
# 333499  https://yt3.ggpht.com/ytc/AIdro_kBJ6lXgh-zF7ee...
#
#                                        authorChannelUrl  \
# 0             http://www.youtube.com/@IndonesianCreator
# 1          http://www.youtube.com/@muhammadfahryzal3498
# 2              http://www.youtube.com/@juliaazzahra7753
# 3               http://www.youtube.com/@user-bw3ze4hc8s
# 4               http://www.youtube.com/@user-ex8yk7tp1b
# ...                                                 ...
# 333495      http://www.youtube.com/@ismanoerfatah._1565
# 333496  http://www.youtube.com/@rahmafitriyanixotkp3148
# 333497       http://www.youtube.com/@ferzaexclusive6434
# 333498             http://www.youtube.com/@sulfadli2171
# 333499         http://www.youtube.com/@nadirasheril1886
#
#                               authorChannelId  canRate viewerRating  \
# 0       {'value': 'UC-z1ubmS-iHMVr83EEwRS2g'}     True         none
# 1       {'value': 'UCWzMGAFOjdLfUWXivsxEI9Q'}     True         none
# 2       {'value': 'UCr1Ir_YJihU1cRgsmrnvPmQ'}     True         none
# 3       {'value': 'UC61igbTMzds0Qi91QQrMisg'}     True         none
# 4       {'value': 'UCwVWpc4IuZPjRM0qRySmLrA'}     True         none
# ...                                       ...      ...          ...
# 333495  {'value': 'UCMb4G1fBwvizjcnOVqrZr7A'}     True         none
# 333496  {'value': 'UCuulF5jlUYn8swz4ppweJ0A'}     True         none
# 333497  {'value': 'UCX-NYKe0VKw_VErNg5q594g'}     True         none
# 333498  {'value': 'UCldoMcS36F7yiYFQCtut8nQ'}     True         none
# 333499  {'value': 'UCcVzJlSjwjvrG9RO85P9vqg'}     True         none
#
#         likeCount           publishedAt             updatedAt
# 0           79203  2020-12-30T10:18:18Z  2021-01-25T08:51:33Z
# 1               0  2024-05-25T00:47:48Z  2024-05-25T00:47:48Z
# 2               0  2024-05-24T14:09:24Z  2024-05-24T14:09:24Z
# 3               1  2024-05-22T07:37:37Z  2024-05-22T07:37:37Z
# 4               0  2024-05-21T13:09:38Z  2024-05-21T13:09:38Z
# ...           ...                   ...                   ...
# 333495          0  2020-12-28T15:30:35Z  2020-12-28T15:30:35Z
# 333496          1  2020-12-28T15:30:35Z  2020-12-28T15:30:35Z
# 333497          0  2020-12-28T15:30:34Z  2020-12-28T15:33:59Z
# 333498          0  2020-12-28T15:30:34Z  2020-12-28T15:30:34Z
# 333499          0  2020-12-28T15:30:34Z  2020-12-28T15:30:34Z
#
# [244034 rows x 14 columns]

# %% [markdown]
# #### Menghapus nilai yang kosong

# %%
df = df.dropna()

# Melihat data yang kosong
df.isnull().sum()
# Out:
# _id                      0
# channelId                0
# videoId                  0
# textDisplay              0
# textOriginal             0
# authorDisplayName        0
# authorProfileImageUrl    0
# authorChannelUrl         0
# authorChannelId          0
# canRate                  0
# viewerRating             0
# likeCount                0
# publishedAt              0
# updatedAt                0
# dtype: int64

# %% [markdown]
# Dari yang awalnya berjumlah 333500 row berkurang menjadi 244034 row

# %% [markdown]
# #### Mengimpan Clean Comments ke MongoDB Local

# %%
# Koneksi ke MongoDB
client = MongoClient(local_url)
db = client[database_name]
collection = db[collection_name]

# Konversi DataFrame ke bentuk dictionary
records = df.to_dict(orient='records')

# Menyisipkan data ke MongoDB
collection.insert_many(records)

print("Data berhasil diimpor ke MongoDB Local.")
# Out:
# Data berhasil diimpor ke MongoDB Local.
