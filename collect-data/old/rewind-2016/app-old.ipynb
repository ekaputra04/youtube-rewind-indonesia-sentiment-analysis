# %% [markdown]
# # Collect data comment Youtube Rewind Indonesia 2016 dengan Google Client API

# %% [markdown]
# #### Inisialisasi variabel API Key dan videoID

# %%
dev = "AIzaSyB39xqCoomzsW73r2J5fAm1RXnmk1m_Htc"
video_id = "1ZIGLm5cuDo"

# %%
# Import library googleapiclient.discovery untuk menggunakan YouTube Data API
import googleapiclient.discovery
# Import library pandas sebagai pd untuk manipulasi data menggunakan DataFrame
import pandas as pd

# Konfigurasi nama layanan API dan versi yang akan digunakan
api_service_name = "youtube"
api_version = "v3"
# Masukkan kunci pengembang Anda
DEVELOPER_KEY = dev

# Membangun objek YouTube API dengan menggunakan kunci pengembang dan versi API yang ditentukan
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Membuat permintaan (request) untuk mendapatkan data komentar dari video tertentu
request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,  # ID video yang akan diambil komentarnya
    maxResults=1999  # Jumlah maksimum komentar yang akan diambil
)

# Inisialisasi list kosong untuk menyimpan komentar
comments = []

# Mengirimkan permintaan dan mendapatkan respons
response = request.execute()

# Mendapatkan komentar dari respons
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    # Menambahkan komentar ke dalam list comments dalam bentuk list
    comments.append([
        comment['authorDisplayName'],  # Nama penulis komentar
        comment['publishedAt'],  # Waktu publikasi komentar
        comment['likeCount'],  # Jumlah suka komentar
        comment['textOriginal'],  # Isi komentar
        public  # Status publikasi komentar
    ])

# Melakukan iterasi untuk mengambil komentar dari halaman berikutnya jika ada
while (1 == 1):
    try:
        nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    except KeyError:
        break  # Keluar dari loop jika tidak ada halaman berikutnya
    
    nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    
    # Membuat permintaan baru dengan menggunakan token halaman berikutnya
    nextRequest = youtube.commentThreads().list(
        part="snippet", 
        videoId=video_id,  # ID video (opsional jika tetap sama dengan sebelumnya)
        maxResults=1999,  # Jumlah maksimum komentar per halaman
        pageToken=nextPageToken  # Token untuk halaman berikutnya
    )
    # Mengirimkan permintaan baru dan mendapatkan respons
    response = nextRequest.execute()
    # Mendapatkan komentar dari respons dan menambahkannya ke dalam list comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])

# Membuat DataFrame dari list comments dengan kolom-kolom yang ditentukan
df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text', 'public'])
# Menampilkan informasi DataFrame seperti jumlah baris dan tipe data kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70127 entries, 0 to 70126
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      70127 non-null  object
#  1   updated_at  70127 non-null  object
#  2   like_count  70127 non-null  int64
#  3   text        70127 non-null  object
#  4   public      70127 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.2+ MB

# %%
df
# Out:
#                                 author            updated_at  like_count  \
# 0                  @achmadrhizaldi8045  2024-04-16T05:40:05Z           0
# 1                       @SyarifMuzamil  2024-04-15T21:45:35Z           0
# 2                       @mcoktukbc6072  2024-04-13T15:08:03Z           1
# 3                     @user-qd5gs5lj2h  2024-04-06T06:05:38Z           2
# 4                  @hendraalfarezz9237  2024-04-02T01:53:07Z           2
# ...                                ...                   ...         ...
# 70122  @lalumuhammadnaveenbomantar1066  2016-12-18T12:16:16Z           0
# 70123         @keisyanoviansyahnur2857  2016-12-18T12:16:16Z           0
# 70124                  @donylukito1058  2016-12-18T12:16:16Z           0
# 70125                         @fjr1746  2016-12-18T12:16:15Z           0
# 70126              @yustrisiadinda7687  2016-12-18T12:16:14Z           1
#
#                                                     text  public
# 0                       Artis tv belum menyerang YouTube    True
# 1                        kangennn cooy ytb jaman dlu😢😭😭😭    True
# 2      Cinta bener sama ni vidio, tidak ada yg namany...    True
# 3                     Heloo guys ku Dateng dari 2024 😂😂😂    True
# 4                            Ramein lagi Manuquin change    True
# ...                                                  ...     ...
# 70122                                           pertamax    True
# 70123                                               Firs    True
# 70124                                            pertama    True
# 70125                                            KEREEEN    True
# 70126                                              first    True
#
# [70127 rows x 5 columns]

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'tAmzTVWU9w5TUSVSBH605kGP-BA',
#  'id': 'Ugg4nMv_w4inkXgCoAEC',
#  'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#   'videoId': '1ZIGLm5cuDo',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'qbOLZXbuqOLX_bShUavNYYt2Eoc',
#    'id': 'Ugg4nMv_w4inkXgCoAEC',
#    'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#     'videoId': '1ZIGLm5cuDo',
#     'textDisplay': 'first',
#     'textOriginal': 'first',
#     'authorDisplayName': '@jessicasantoso8447',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mL7L1HlsUp1DoK7h0UPxn5D_mz9XzycsYc12b_KYHvwew=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@jessicasantoso8447',
#     'authorChannelId': {'value': 'UCL3w-gDnHgD9ryQ1igxxRXg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2016-12-18T12:16:19Z',
#     'updatedAt': '2016-12-18T12:16:19Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                  author            updated_at  like_count  \
# 66674          @Tim2one  2016-12-18T12:34:19Z       16026
# 10131      @TheJooomers  2020-07-06T13:29:11Z       15016
# 24189  @famousytber3336  2018-12-08T08:44:25Z       12321
# 7427     @fxntastic7111  2020-11-28T14:02:14Z        7823
# 13373      @TheJooomers  2019-10-14T05:37:10Z        7360
# 22741        @SanzLemon  2018-12-14T15:48:37Z        6545
# 24395            @dipqi  2018-12-07T02:31:54Z        6088
# 67187  @SaaihHalilintar  2016-12-18T12:30:40Z        5595
# 26832      @GvmzyGaming  2018-09-13T13:30:48Z        5593
# 22524       @Kenandgrat  2018-12-14T16:11:22Z        5019
#
#                                                     text  public
# 66674      Proud to direct this baby. SALUTE TO YOU ALL!    True
# 10131  2020 Harus begini lagi yah :) yang 2016 ... Go...    True
# 24189  Yang Kecewa Sama YouTube Rewind Global 2018 Ka...    True
# 7427   Let's be honest, kita semua merindukan youtube...    True
# 13373                       Still best :) - October 2019    True
# 22741  Yang udah nonton YT Rewind 2018 dr Live Tahuka...    True
# 24395                         masih best sampe sekarang.    True
# 67187  Memang Chandraliow dan Rezaoktovian yang palin...    True
# 26832  Siapa yang nonton September 2018??\nApakah kal...    True
# 22524                                         Kangen :'(    True

# %% [markdown]
# #### Menyimpan DataFrame ke dalam file JSON

# %%
df.to_json('comments-2016.json', orient='records', lines=True)

# %%
import json

# Membuat list of dictionaries dengan key yang diinginkan
comments_data = []
for comment in comments:
    comment_dict = {
        'video': video_id,
        'author': comment[0],
        'updated_at': comment[1],
        'like_count': comment[2],
        'text': comment[3],
        'public': comment[4]
    }
    comments_data.append(comment_dict)

# Membuat dictionary yang berisi key 'comments' dengan nilai dari comments_data
data = {'comments': comments_data}

# Menyimpan dictionary ke dalam file JSON
with open('comments.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2016"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB.")
# Out:
# Data berhasil diimpor ke MongoDB.

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB Atlas

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb+srv://ekaputrajuniawan:9yyb7lj6k557n45i@cluster0.dboezoc.mongodb.net/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2016"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB Atlas.")
# Out:
# Data berhasil diimpor ke MongoDB Atlas.
