# %% [markdown]
# # Collect data comment Youtube Rewind Indonesia 2018 dengan Google Client API

# %% [markdown]
# #### Inisialisasi variabel API Key dan videoID

# %%
dev = "AIzaSyB39xqCoomzsW73r2J5fAm1RXnmk1m_Htc"
video_id = "mCyITaDib7M"

# %%
# Import library googleapiclient.discovery untuk menggunakan YouTube Data API
import googleapiclient.discovery
# Import library pandas sebagai pd untuk manipulasi data menggunakan DataFrame
import pandas as pd

# Konfigurasi nama layanan API dan versi yang akan digunakan
api_service_name = "youtube"
api_version = "v3"
# Masukkan kunci pengembang Anda
DEVELOPER_KEY = dev

# Membangun objek YouTube API dengan menggunakan kunci pengembang dan versi API yang ditentukan
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Membuat permintaan (request) untuk mendapatkan data komentar dari video tertentu
request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,  # ID video yang akan diambil komentarnya
    maxResults=1999  # Jumlah maksimum komentar yang akan diambil
)

# Inisialisasi list kosong untuk menyimpan komentar
comments = []

# Mengirimkan permintaan dan mendapatkan respons
response = request.execute()

# Mendapatkan komentar dari respons
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    # Menambahkan komentar ke dalam list comments dalam bentuk list
    comments.append([
        comment['authorDisplayName'],  # Nama penulis komentar
        comment['publishedAt'],  # Waktu publikasi komentar
        comment['likeCount'],  # Jumlah suka komentar
        comment['textOriginal'],  # Isi komentar
        public  # Status publikasi komentar
    ])

# Melakukan iterasi untuk mengambil komentar dari halaman berikutnya jika ada
while (1 == 1):
    try:
        nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    except KeyError:
        break  # Keluar dari loop jika tidak ada halaman berikutnya
    
    nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    
    # Membuat permintaan baru dengan menggunakan token halaman berikutnya
    nextRequest = youtube.commentThreads().list(
        part="snippet", 
        videoId=video_id,  # ID video (opsional jika tetap sama dengan sebelumnya)
        maxResults=1999,  # Jumlah maksimum komentar per halaman
        pageToken=nextPageToken  # Token untuk halaman berikutnya
    )
    # Mengirimkan permintaan baru dan mendapatkan respons
    response = nextRequest.execute()
    # Mendapatkan komentar dari respons dan menambahkannya ke dalam list comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])

# Membuat DataFrame dari list comments dengan kolom-kolom yang ditentukan
df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text', 'public'])
# Menampilkan informasi DataFrame seperti jumlah baris dan tipe data kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111463 entries, 0 to 111462
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   author      111463 non-null  object
#  1   updated_at  111463 non-null  object
#  2   like_count  111463 non-null  int64
#  3   text        111463 non-null  object
#  4   public      111463 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 3.5+ MB

# %%
df
# Out:
#                     author            updated_at  like_count  \
# 0        @Selamat.tinggal.  2024-04-07T01:33:44Z           1
# 1             @melaady5356  2024-03-05T15:52:12Z           1
# 2       @muhammadhafis2418  2024-03-02T16:06:11Z           2
# 3           @udinpetot5804  2024-03-01T00:38:38Z           3
# 4            @yudacipz9252  2024-02-25T02:06:00Z           3
# ...                    ...                   ...         ...
# 111458     @erlanggasp5492  2018-12-14T15:26:35Z           4
# 111459          @rianr7336  2018-12-14T15:26:35Z           0
# 111460          @nick.8697  2018-12-14T15:26:35Z           0
# 111461  @azaryapranata1108  2018-12-14T15:26:35Z           0
# 111462    @mishaeljehoshua  2018-12-14T15:26:27Z          48
#
#                                                      text  public
# 0                                                       P    True
# 1          Hallo, 2024 kangen lihat karya ericko lim hehe    True
# 2       Oh gw inget ,video ini gw kiat pake hp pertama...    True
# 3       Sebelum korona menyerang, sebelum hidup gw ber...    True
# 4                                                   2024?    True
# ...                                                   ...     ...
# 111458                          setelah lama menanti wkwk    True
# 111459                                             mantap    True
# 111460                                              Aloha    True
# 111461                                 PINK GUY - セックス大好き    True
# 111462  SMA SANTA MARIA-Pekanbaru selalu memberikan ya...    True
#
# [111463 rows x 5 columns]

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'Uu6_aZqCuLMcJ149n3JQ81rAzU8',
#  'id': 'Ugzdo7E7bSANISqDhXt4AaABAg',
#  'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#   'videoId': 'mCyITaDib7M',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'Ye_U-Z_bc4YihFegn02QyWMPTyg',
#    'id': 'Ugzdo7E7bSANISqDhXt4AaABAg',
#    'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#     'videoId': 'mCyITaDib7M',
#     'textDisplay': 'Dude',
#     'textOriginal': 'Dude',
#     'authorDisplayName': '@mishaeljehoshua',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ppU9UKoTkEeWvS_8JSPAindV3BJIdfZ5tGNtiZUdgSvgQU_9IH27HgtVrZwi4LSo4tOjiU-Fpw=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@mishaeljehoshua',
#     'authorChannelId': {'value': 'UCNp_TMaBm_ecH1ta4V_FZ1A'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2018-12-14T15:26:47Z',
#     'updatedAt': '2018-12-14T15:26:47Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                         author            updated_at  like_count  \
# 5824                 @TINATAjr  2020-12-28T17:12:18Z       28931
# 87771      @skinnyindonesian24  2018-12-14T16:49:04Z       27106
# 85188             @NessieJudge  2018-12-14T17:13:12Z       11236
# 14942                   @xradt  2019-06-07T16:29:20Z       11004
# 6335          @yakalitvesports  2020-12-24T13:06:23Z        9041
# 20734                  @wbaaay  2018-12-29T14:15:45Z        8370
# 29101      @wrestlingmatch6913  2018-12-18T07:44:19Z        7575
# 83129          @kevinhendrawan  2018-12-14T17:38:59Z        5276
# 5071   @elsaseptianisilvia5703  2020-12-29T14:40:24Z        5263
# 3622              @kzaaa-nm9bg  2021-01-02T15:23:08Z        5002
#
#                                                     text  public
# 5824   Jumlah orang yg habis nonton yt reward 2020 te...    True
# 87771                         Hidup YouTubers Indonesia!    True
# 85188                              Kisses from France ♥️    True
# 14942  Hapus aja deh biar yg lain penasaran wkwk\n\nE...    True
# 6335                             Menantikan Rewind 2020🔥    True
# 20734  List Lagu Youtube Rewind INDONESIA 2018 :\r\n\...    True
# 29101  DAFTAR LAGU YTR INDO 2018\n\n0:05 = Post Malon...    True
# 83129           Congrats buat semua Tim yang bertugas :)    True
# 5071   Gausah dibandingin sih semuanya bagus, udah gi...    True
# 3622                   gua kangen suasana tanpa masker:(    True

# %% [markdown]
# #### Menyimpan DataFrame ke dalam file JSON

# %%
df.to_json('comments-2018.json', orient='records', lines=True)

# %%
import json

# Membuat list of dictionaries dengan key yang diinginkan
comments_data = []
for comment in comments:
    comment_dict = {
        'video': video_id,
        'author': comment[0],
        'updated_at': comment[1],
        'like_count': comment[2],
        'text': comment[3],
        'public': comment[4]
    }
    comments_data.append(comment_dict)

# Membuat dictionary yang berisi key 'comments' dengan nilai dari comments_data
data = {'comments': comments_data}

# Menyimpan dictionary ke dalam file JSON
with open('comments.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2018"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB.")
# Out:
# Data berhasil diimpor ke MongoDB.

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB Atlas

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb+srv://ekaputrajuniawan:9yyb7lj6k557n45i@cluster0.dboezoc.mongodb.net/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2018"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB Atlas.")
# Out:
# Data berhasil diimpor ke MongoDB.
