# %% [markdown]
# # Collect data comment Youtube Rewind Indonesia 2015 dengan Google Client API

# %% [markdown]
# #### Inisialisasi variabel API Key dan videoID

# %%
dev = "AIzaSyB39xqCoomzsW73r2J5fAm1RXnmk1m_Htc"
video_id = "fNX6Gu2F7A8"

# %%
# Import library googleapiclient.discovery untuk menggunakan YouTube Data API
import googleapiclient.discovery
# Import library pandas sebagai pd untuk manipulasi data menggunakan DataFrame
import pandas as pd

# Konfigurasi nama layanan API dan versi yang akan digunakan
api_service_name = "youtube"
api_version = "v3"
# Masukkan kunci pengembang Anda
DEVELOPER_KEY = dev

# Membangun objek YouTube API dengan menggunakan kunci pengembang dan versi API yang ditentukan
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Membuat permintaan (request) untuk mendapatkan data komentar dari video tertentu
request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,  # ID video yang akan diambil komentarnya
    maxResults=1999  # Jumlah maksimum komentar yang akan diambil
)

# Inisialisasi list kosong untuk menyimpan komentar
comments = []

# Mengirimkan permintaan dan mendapatkan respons
response = request.execute()

# Mendapatkan komentar dari respons
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    # Menambahkan komentar ke dalam list comments dalam bentuk list
    comments.append([
        comment['authorDisplayName'],  # Nama penulis komentar
        comment['publishedAt'],  # Waktu publikasi komentar
        comment['likeCount'],  # Jumlah suka komentar
        comment['textOriginal'],  # Isi komentar
        public  # Status publikasi komentar
    ])

# Melakukan iterasi untuk mengambil komentar dari halaman berikutnya jika ada
while (1 == 1):
    try:
        nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    except KeyError:
        break  # Keluar dari loop jika tidak ada halaman berikutnya
    
    nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    
    # Membuat permintaan baru dengan menggunakan token halaman berikutnya
    nextRequest = youtube.commentThreads().list(
        part="snippet", 
        videoId=video_id,  # ID video (opsional jika tetap sama dengan sebelumnya)
        maxResults=1999,  # Jumlah maksimum komentar per halaman
        pageToken=nextPageToken  # Token untuk halaman berikutnya
    )
    # Mengirimkan permintaan baru dan mendapatkan respons
    response = nextRequest.execute()
    # Mendapatkan komentar dari respons dan menambahkannya ke dalam list comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])

# Membuat DataFrame dari list comments dengan kolom-kolom yang ditentukan
df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text', 'public'])
# Menampilkan informasi DataFrame seperti jumlah baris dan tipe data kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28408 entries, 0 to 28407
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      28408 non-null  object
#  1   updated_at  28408 non-null  object
#  2   like_count  28408 non-null  int64
#  3   text        28408 non-null  object
#  4   public      28408 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 915.6+ KB

# %%
df
# Out:
#                            author            updated_at  like_count  \
# 0                       @wibu4353  2024-04-15T09:56:11Z           0
# 1      @ginawardahtulhumairoh3722  2024-04-14T14:43:44Z           0
# 2                    @alfiqri5913  2024-04-11T13:56:04Z           1
# 3              @dastananindra1566  2024-04-07T06:20:23Z           1
# 4                       @farisnst  2024-04-01T22:02:47Z           1
# ...                           ...                   ...         ...
# 28403           @GantplayBlogspot  2015-12-11T06:02:11Z           0
# 28404           @ramandahafiz6293  2015-12-11T06:02:07Z           0
# 28405                    @e4rtz84  2015-12-11T06:02:05Z           1
# 28406      @pricillaoktaviani2376  2015-12-11T06:02:03Z           0
# 28407           @abayartsgame4609  2015-12-11T06:02:01Z           1
#
#                                                 text  public
# 0                                    salam dari 2024    True
# 1             Hahaha...btw niii udah 2024,GK kerasa😢    True
# 2                                           the best    True
# 3                                Sorry telat 9 tahun    True
# 4      Ah gila udah mau 9 tahun masih apal lagu nya😂    True
# ...                                              ...     ...
# 28403                                      Mantep :v    True
# 28404                                         Boom !    True
# 28405                        anjing canggih waaahhhh    True
# 28406                                          firat    True
# 28407                                              1    True
#
# [28408 rows x 5 columns]

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'tvWQ-tnUObutOgYyO03kja2LqD4',
#  'id': 'UghcmRka9Ek3Z3gCoAEC',
#  'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#   'videoId': 'fNX6Gu2F7A8',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'Il8v7RaaymXYumLMGt9YNFcLE_0',
#    'id': 'UghcmRka9Ek3Z3gCoAEC',
#    'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#     'videoId': 'fNX6Gu2F7A8',
#     'textDisplay': 'first?',
#     'textOriginal': 'first?',
#     'authorDisplayName': '@daffareyhan7744',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l9Z8Ac4EImMWw3VYEE5x8nVk5OR6wcsqYMBzc2GlRxb7c=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@daffareyhan7744',
#     'authorChannelId': {'value': 'UCU5ZSalOcKyOigjN4pYlP1A'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2015-12-11T06:02:12Z',
#     'updatedAt': '2015-12-11T06:02:12Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                         author            updated_at  like_count  \
# 27996                 @Tim2one  2015-12-11T06:17:47Z       15401
# 9668     @PUTRASIREGARMERAKYAT  2018-12-15T03:28:03Z        7482
# 24833               @corbuzier  2015-12-12T13:39:04Z        7058
# 6485              @NessieJudge  2020-05-16T18:28:51Z        6573
# 4104             @iimpostor464  2020-12-29T08:20:08Z        6567
# 4853           @TeguhPrakoso27  2020-12-11T12:41:09Z        6124
# 4321             @galuhcuisine  2020-12-29T03:22:53Z        5444
# 27529        @bayuekomoektito1  2015-12-11T06:52:58Z        4786
# 27886      @skinnyindonesian24  2015-12-11T06:24:14Z        3887
# 5053   @19.kadekagussuardika76  2020-10-09T13:30:28Z        3312
#
#                                                     text  public
# 27996          Ini semua kita persembahkan untuk kalian!    True
# 9668   SIAPA YANG NONTON INI DI DESEMBER 2018 KARENA ...    True
# 24833  Very proud of all youngsters here.. Keep the g...    True
# 6485                                              ♥️♥️♥️    True
# 4104   Siapa yg kesini karena udh liat yg YOUTUBE REW...    True
# 4853                                     good old time ~    True
# 4321                                         Nostalgia 😆    True
# 27529                   Yeah! Hidup YOUTUBERS INDONESIA!    True
# 27886  Boom boom boom! Indonesian YouTubers gak kalah...    True
# 5053                Brp orang yang Nostalgia merapat \n👇    True

# %% [markdown]
# #### Menyimpan DataFrame ke dalam file JSON

# %%
df.to_json('comments-2015.json', orient='records', lines=True)

# %%
import json

# Membuat list of dictionaries dengan key yang diinginkan
comments_data = []
for comment in comments:
    comment_dict = {
        'video': '',
        'author': comment[0],
        'updated_at': comment[1],
        'like_count': comment[2],
        'text': comment[3],
        'public': comment[4]
    }
    comments_data.append(comment_dict)

# Membuat dictionary yang berisi key 'comments' dengan nilai dari comments_data
data = {'comments': comments_data}

# Menyimpan dictionary ke dalam file JSON
with open('comments.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2015"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB.")
# Out:
# Data berhasil diimpor ke MongoDB.

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB Atlas

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb+srv://ekaputrajuniawan:9yyb7lj6k557n45i@cluster0.dboezoc.mongodb.net/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2015"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB Atlas.")
# Out:
# Data berhasil diimpor ke MongoDB.
