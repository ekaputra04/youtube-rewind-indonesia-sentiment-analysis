# %% [markdown]
# # Collect data comment Youtube Rewind Indonesia 2021 dengan Google Client API

# %% [markdown]
# #### Inisialisasi variabel API Key dan videoID

# %% [markdown]
# API KEY baru karena yang sebelumnya sudah kena limit

# %%
dev = "AIzaSyCXsGBmQIa-sHqccdLOK1EY7E0F6qE4fsc"
video_id = "IPZO85HFM4w"

# %%
# Import library googleapiclient.discovery untuk menggunakan YouTube Data API
import googleapiclient.discovery
# Import library pandas sebagai pd untuk manipulasi data menggunakan DataFrame
import pandas as pd

# Konfigurasi nama layanan API dan versi yang akan digunakan
api_service_name = "youtube"
api_version = "v3"
# Masukkan kunci pengembang Anda
DEVELOPER_KEY = dev

# Membangun objek YouTube API dengan menggunakan kunci pengembang dan versi API yang ditentukan
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# Membuat permintaan (request) untuk mendapatkan data komentar dari video tertentu
request = youtube.commentThreads().list(
    part="snippet",
    videoId=video_id,  # ID video yang akan diambil komentarnya
    maxResults=100  # Jumlah maksimum komentar yang akan diambil
)

# Inisialisasi list kosong untuk menyimpan komentar
comments = []

# Mengirimkan permintaan dan mendapatkan respons
response = request.execute()

# Mendapatkan komentar dari respons
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    # Menambahkan komentar ke dalam list comments dalam bentuk list
    comments.append([
        comment['authorDisplayName'],  # Nama penulis komentar
        comment['publishedAt'],  # Waktu publikasi komentar
        comment['likeCount'],  # Jumlah suka komentar
        comment['textOriginal'],  # Isi komentar
        public  # Status publikasi komentar
    ])

# Melakukan iterasi untuk mengambil komentar dari halaman berikutnya jika ada
while (1 == 1):
    try:
        nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    except KeyError:
        break  # Keluar dari loop jika tidak ada halaman berikutnya
    
    nextPageToken = response['nextPageToken']  # Mengambil token untuk halaman berikutnya
    
    # Membuat permintaan baru dengan menggunakan token halaman berikutnya
    nextRequest = youtube.commentThreads().list(
        part="snippet", 
        videoId=video_id,  # ID video (opsional jika tetap sama dengan sebelumnya)
        maxResults=100,  # Jumlah maksimum komentar per halaman
        pageToken=nextPageToken  # Token untuk halaman berikutnya
    )
    # Mengirimkan permintaan baru dan mendapatkan respons
    response = nextRequest.execute()
    # Mendapatkan komentar dari respons dan menambahkannya ke dalam list comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])

# Membuat DataFrame dari list comments dengan kolom-kolom yang ditentukan
df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text', 'public'])
# Menampilkan informasi DataFrame seperti jumlah baris dan tipe data kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89962 entries, 0 to 89961
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      89962 non-null  object
#  1   updated_at  89962 non-null  object
#  2   like_count  89962 non-null  int64
#  3   text        89962 non-null  object
#  4   public      89962 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.8+ MB

# %%
df
# Out:
#                         author            updated_at  like_count  \
# 0           @IndonesianCreator  2021-12-30T12:07:00Z       52497
# 1             @user-ko2ss2mv8d  2024-04-11T15:18:11Z           1
# 2             @user-ko2ss2mv8d  2024-04-11T15:18:11Z           1
# 3      @friedrichnietzsche8339  2024-04-10T21:06:44Z           1
# 4                 @murisy_here  2024-04-08T10:14:27Z           2
# ...                        ...                   ...         ...
# 89957                 @Rifz4HY  2021-12-30T12:05:20Z           2
# 89958         @friskacahyu5874  2021-12-30T12:05:09Z           2
# 89959               @abyzar689  2021-12-30T12:05:07Z           2
# 89960      @muhammadfikrin9249  2021-12-30T12:05:04Z           3
# 89961        @revaismasari5004  2021-12-30T12:04:15Z           4
#
#                                                     text  public
# 0      REWIND INDONESIA 2021.#RI2021\nYuk bikin video...    True
# 1                          Lebaran 2024 masih nonton ini    True
# 2                          Lebaran 2024 masih nonton ini    True
# 3      Miris gak sih Sponsor Scarlett tapi ada YouTub...    True
# 4      10:48 \nRI 2021 jd pahlawan\nRI 2023 jadi vill...    True
# ...                                                  ...     ...
# 89957                             KEREN PARAH REWINDNYA🔥    True
# 89958                                              Huhuu    True
# 89959                                            gasabar    True
# 89960                                              First    True
# 89961                                       Gasabar plis    True
#
# [89962 rows x 5 columns]

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'wPuvXGoGXsvwCwuVBjoR3xZH6V4',
#  'id': 'Ugxd_yldDSUWJU9tjyt4AaABAg',
#  'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#   'videoId': 'IPZO85HFM4w',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'X2TaAO0jW4ICHXa5giB3h2YHcrw',
#    'id': 'Ugxd_yldDSUWJU9tjyt4AaABAg',
#    'snippet': {'channelId': 'UC-z1ubmS-iHMVr83EEwRS2g',
#     'videoId': 'IPZO85HFM4w',
#     'textDisplay': 'WAH KEREN BANGET 👍👍',
#     'textOriginal': 'WAH KEREN BANGET 👍👍',
#     'authorDisplayName': '@OwenHalim',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/jFBwMhH7PYAsNzlt9fUv-HsNlPRqQfs_Kqq9BKjGBpgE0G1c3QqtFbMDlcaU52UH-VTryzDX=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@OwenHalim',
#     'authorChannelId': {'value': 'UCU2p70Gx5xO6ohu-dNtZPDA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 3,
#     'publishedAt': '2021-12-30T12:17:40Z',
#     'updatedAt': '2021-12-30T12:17:40Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                     author            updated_at  like_count  \
# 75035          @YuraYunita  2021-12-30T14:42:10Z       53845
# 0       @IndonesianCreator  2021-12-30T12:07:00Z       52497
# 89935   @IndonesianCreator  2021-12-30T12:07:00Z       52497
# 85952    @ChristopherDevin  2021-12-30T13:26:43Z       46705
# 70916          @NatyaShina  2021-12-30T15:20:39Z       18063
# 83344     @nihongomantappu  2021-12-30T13:43:31Z       17560
# 64612         @NessieJudge  2021-12-30T16:48:03Z       12050
# 85788       @AfifYulistian  2021-12-30T13:28:04Z       11645
# 72589  @AndikaHonda18video  2021-12-30T15:03:37Z        9951
# 89577     @VINCENT_FRAZIER  2021-12-30T12:36:50Z        6532
#
#                                                     text  public
# 75035  Terima kasih untuk semua yang terlibat di kary...    True
# 0      REWIND INDONESIA 2021.#RI2021\nYuk bikin video...    True
# 89935  REWIND INDONESIA 2021.#RI2021\nYuk bikin video...    True
# 85952  Kalian semua gokil. Gak nyangka video Rewind b...    True
# 70916  Sebuah persembahan dari dan untuk Indonesia. M...    True
# 83344                               MUANTAPPU JIWAAAAA🔥🔥    True
# 64612  2021 nearly killed me. Pretty accurate. Ha!\nb...    True
# 85788  Berasa nonton film , 😭 keren bgt woi! Terima k...    True
# 72589  Semua rewind indonesia itu bagus dan sesuai sa...    True
# 89577  pandemi tidak jadi halangan untuk membuat yout...    True

# %% [markdown]
# #### Menyimpan DataFrame ke dalam file JSON

# %%
df.to_json('comments-2021.json', orient='records', lines=True)

# %%
import json

# Membuat list of dictionaries dengan key yang diinginkan
comments_data = []
for comment in comments:
    comment_dict = {
        'video': video_id,
        'author': comment[0],
        'updated_at': comment[1],
        'like_count': comment[2],
        'text': comment[3],
        'public': comment[4]
    }
    comments_data.append(comment_dict)

# Membuat dictionary yang berisi key 'comments' dengan nilai dari comments_data
data = {'comments': comments_data}

# Menyimpan dictionary ke dalam file JSON
with open('comments.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# ## Menyimpan json ke dalam MongoDB

# %%
import json
from pymongo import MongoClient

# Koneksi ke MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["youtube_rewind_indonesia"]
collection = db["collect_2021"]

# Membaca file JSON
with open("comments.json", "r") as file:
    data = json.load(file)
    comments = data["comments"]

# Menyisipkan data ke MongoDB
collection.insert_many(comments)

print("Data berhasil diimpor ke MongoDB.")
# Out:
# Data berhasil diimpor ke MongoDB.
