# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
# collection_name = 'full_labeling_2020'
collection_name = 'labeling_2020'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
# label_counts = df_labeled['predicted_label'].value_counts()
label_counts = df_labeled['label'].value_counts()
label_counts
# Out:
# label
# netral     991
# positif    911
# negatif     98
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 911
# Jumlah komentar negatif: 98
# Jumlah komentar netral: 991

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
# df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
# df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
# df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

df_positif = df_labeled[df_labeled['label'] == 'positif']
df_negatif = df_labeled[df_labeled['label'] == 'negatif']
df_netral = df_labeled[df_labeled['label'] == 'netral']

# %%
df_positif
# Out:
#                            _id  \
# 0     66519bf84bec1f5ab8644847
# 2     66519bf84bec1f5ab8644849
# 4     66519bf84bec1f5ab864484b
# 5     66519bf84bec1f5ab864484c
# 7     66519bf84bec1f5ab864484e
# ...                        ...
# 1987  66519bf84bec1f5ab864500a
# 1989  66519bf84bec1f5ab864500c
# 1991  66519bf84bec1f5ab864500e
# 1994  66519bf84bec1f5ab8645011
# 1998  66519bf84bec1f5ab8645015
#
#                                            textOriginal    label
# 0                                keren ending nya sedih  positif
# 2                                  kep it trending guys  positif
# 4                                          banget keren  positif
# 5                                      ini keren banget  positif
# 7                 merinding nontonya awal akhir god job  positif
# ...                                                 ...      ...
# 1987  keren sangat lucu rua sedih ada haru keren san...  positif
# 1989  dream come true because of work together rise ...  positif
# 1991                                   keren banget woi  positif
# 1994                                            muantul  positif
# 1998                                        keren bnget  positif
#
# [911 rows x 3 columns]

# %%
df_negatif
# Out:
#                            _id  \
# 83    66519bf84bec1f5ab864489a
# 165   66519bf84bec1f5ab86448ec
# 170   66519bf84bec1f5ab86448f1
# 240   66519bf84bec1f5ab8644937
# 244   66519bf84bec1f5ab864493b
# ...                        ...
# 1907  66519bf84bec1f5ab8644fba
# 1910  66519bf84bec1f5ab8644fbd
# 1912  66519bf84bec1f5ab8644fbf
# 1925  66519bf84bec1f5ab8644fcc
# 1940  66519bf84bec1f5ab8644fdb
#
#                                            textOriginal    label
# 83                            wah cok gc nya cok aswlah  negatif
# 165                                       udah gila boy  negatif
# 170                          yang kurang tebak apa hayo  negatif
# 240                                       hu anak kecil  negatif
# 244   gw mau kritik kakakakak video konsep nya kayak...  negatif
# ...                                                 ...      ...
# 1907  kecewa yotuber sukan kagak masuktapi tetep bag...  negatif
# 1910                                        gilak parah  negatif
# 1912              kampret sih adegan skiny keluar pintu  negatif
# 1925                             eh erikontod mana nich  negatif
# 1940                                 ericko lim mana oi  negatif
#
# [98 rows x 3 columns]

# %%
df_netral
# Out:
#                            _id  \
# 1     66519bf84bec1f5ab8644848
# 3     66519bf84bec1f5ab864484a
# 6     66519bf84bec1f5ab864484d
# 9     66519bf84bec1f5ab8644850
# 12    66519bf84bec1f5ab8644853
# ...                        ...
# 1993  66519bf84bec1f5ab8645010
# 1995  66519bf84bec1f5ab8645012
# 1996  66519bf84bec1f5ab8645013
# 1997  66519bf84bec1f5ab8645014
# 1999  66519bf84bec1f5ab8645016
#
#                                            textOriginal   label
# 1     komen bisa kalian baca antara ratus ribu komen...  netral
# 3                                            ngueri cok  netral
# 6                                      ga bobon santoso  netral
# 9                        mah rekor hari udah jt viewers  netral
# 12    tadi liat oto gledek auto dislike terus cok mu...  netral
# ...                                                 ...     ...
# 1993    youtube rewind terbaiksaya merinding menontonya  netral
# 1995  udah nonton kali sekarang nonton karna keluar ...  netral
# 1996               coba lesti nyi cepet dah trendingnya  netral
# 1997                                             petcah  netral
# 1999                              kok belm trending sih  netral
#
# [991 rows x 3 columns]
