# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
collection_name = 'full_labeling_2020'
# collection_name = 'labeling_2020'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
label_counts = df_labeled['predicted_label'].value_counts()
# label_counts = df_labeled['label'].value_counts()
label_counts
# Out:
# predicted_label
# positif    5043
# netral     4907
# negatif      50
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 5043
# Jumlah komentar negatif: 50
# Jumlah komentar netral: 4907

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

# df_positif = df_labeled[df_labeled['label'] == 'positif']
# df_negatif = df_labeled[df_labeled['label'] == 'negatif']
# df_netral = df_labeled[df_labeled['label'] == 'netral']

# %%
df_positif
# Out:
#                            _id                           textOriginal  \
# 2     66519bf84bec1f5ab8644849                   kep it trending guys
# 4     66519bf84bec1f5ab864484b                           banget keren
# 5     66519bf84bec1f5ab864484c                       ini keren banget
# 7     66519bf84bec1f5ab864484e  merinding nontonya awal akhir god job
# 8     66519bf84bec1f5ab864484f              nih video keren parah sih
# ...                        ...                                    ...
# 9993  66519bf84bec1f5ab8646f50                             keren abis
# 9994  66519bf84bec1f5ab8646f51                      semangat karya bg
# 9995  66519bf84bec1f5ab8646f52                           bagus banget
# 9996  66519bf84bec1f5ab8646f53                             days times
# 9998  66519bf84bec1f5ab8646f55                           keren banget
#
#      predicted_label
# 2            positif
# 4            positif
# 5            positif
# 7            positif
# 8            positif
# ...              ...
# 9993         positif
# 9994         positif
# 9995         positif
# 9996         positif
# 9998         positif
#
# [5043 rows x 3 columns]

# %%
df_negatif
# Out:
#                            _id  \
# 312   66519bf84bec1f5ab864497f
# 362   66519bf84bec1f5ab86449b1
# 2650                                 heran sama dislike         negatif
# 2736                   kurang ideologis terlalu dangkal         negatif
# 3288                   iklan tik tok diyutub nga rewind         negatif
# 3483                                  dislike gada otak         negatif
# 3748                       yg ngedislike iri bilang bos         negatif
# 3983                mungkin dislike iri mereka trending         negatif
# 4110                seng dislike matane picek hati nkri         negatif
# 4426                               ga erti sama dislike         negatif
# 4622                    andai aja corona mimpi buruk gw         negatif
# 4771                              asw potong iklan mulu         negatif
# 5052                                   dislike aneh sih         negatif
# 5067                             nge dislike fiks bocil         negatif
# 5209                                     worst yearalso         negatif
# 5626                       kok ga ngajak youtuber artis         negatif
# 5787              sekarang banyak artis alay ngeyoutube         negatif
# 5804                                        dislike fix         negatif
# 6097                                 cringe just cringe         negatif
# 6299                                      video dislike         negatif
# 6309                                 serang lama serang         negatif
# 6685                                kok ada dislike sad         negatif
# 7842            part paling cringe cringe cringe cringe         negatif
# 7915                 kok banyak orang nge dislike video         negatif
# 7987                          sembako sampah gada anjir         negatif
# 8034                                       bocil goblok         negatif
# 8079                     ngedislike orang kurang asupan         negatif
# 8262                        gelut sama yang nge dislike         negatif
# 8749             fix dislike fans gipe uwoy ytber belah         negatif
# 8767                            nge dislike engak otakv         negatif
# 8858                     kok ada dislike gtu aneh emang         negatif
# 8953            gua yakin dislike bocil ama emak leslar         negatif
# 9205                               tiktok rewind inimah         negatif
# 9265                                 jelek konsep jelas         negatif
# 9322                       mungkin dislike beban negara         negatif
# 9350                  yg dislike gk erti seni kalau mah         negatif
# 9519                                   sape sih dislike         negatif
# 9659                               dislike matane picek         negatif
# 9676                                     hah rb dislike         negatif

# %%
df_netral
# Out:
#                            _id  \
# 0     66519bf84bec1f5ab8644847
# 1     66519bf84bec1f5ab8644848
# 3     66519bf84bec1f5ab864484a
# 6     66519bf84bec1f5ab864484d
# 9     66519bf84bec1f5ab8644850
# ...                        ...
# 9987  66519bf84bec1f5ab8646f4a
# 9990  66519bf84bec1f5ab8646f4d
# 9991  66519bf84bec1f5ab8646f4e
# 9997  66519bf84bec1f5ab8646f54
# 9999  66519bf84bec1f5ab8646f56
#
#                                            textOriginal predicted_label
# 0                                keren ending nya sedih          netral
# 1     komen bisa kalian baca antara ratus ribu komen...          netral
# 3                                            ngueri cok          netral
# 6                                      ga bobon santoso          netral
# 9                        mah rekor hari udah jt viewers          netral
# ...                                                 ...             ...
# 9987                              kayak balik masa lalu          netral
# 9990       gw ulangulanh tep ae ga bosen pen liat terus          netral
# 9991  rewind indonesia paling sukamungkin aulion jad...          netral
# 9997           oke bagus ngak kayak taun kemaren mantap          netral
# 9999                                          chefs kis          netral
#
# [4907 rows x 3 columns]
