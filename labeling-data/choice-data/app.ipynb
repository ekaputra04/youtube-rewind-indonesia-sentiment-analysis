# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
collection_name = 'full_labeling_2015'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
label_counts = df_labeled['predicted_label'].value_counts()
label_counts
# Out:
# predicted_label
# netral     7842
# positif    1901
# negatif     257
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 1901
# Jumlah komentar negatif: 257
# Jumlah komentar netral: 7842

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

# %%
df_positif
# Out:
#                            _id  \
# 1     6651837620ee1df904ba499b
# 4     6651837620ee1df904ba499e
# 10    6651837620ee1df904ba49a4
# 11    6651837620ee1df904ba49a5
# 12    6651837620ee1df904ba49a6
# ...                        ...
# 9934  6651837620ee1df904ba7068
# 9950  6651837620ee1df904ba7078
# 9984  6651837620ee1df904ba709a
# 9988  6651837620ee1df904ba709e
# 9994  6651837620ee1df904ba70a4
#
#                                            textOriginal predicted_label
# 1                          rewind ter the best sih nice         positif
# 4                 anjir keren gilak youtubers indonesia         positif
# 10                         wow seru banget video kompak         positif
# 11    am only one who always watching this video al ...         positif
# 12                 wow kerensnjshshsjsh aku suka banget         positif
# ...                                                 ...             ...
# 9934       keren bangat tetap karya youtubers indonesia         positif
# 9950                                  musicnya the best         positif
# 9984  suka pesan moral kena asap sempat landa wilaya...         positif
# 9988                                         keren abis         positif
# 9994                        wow mantap banget youtubers         positif
#
# [1901 rows x 3 columns]

# %%
df_negatif
# Out:
#                            _id  \
# 3     6651837620ee1df904ba499d
# 37    6651837620ee1df904ba49bf
# 50    6651837620ee1df904ba49cc
# 88    6651837620ee1df904ba49f2
# 90    6651837620ee1df904ba49f4
# ...                        ...
# 9738  6651837620ee1df904ba6fa4
# 9809  6651837620ee1df904ba6feb
# 9913  6651837620ee1df904ba7053
# 9925  6651837620ee1df904ba705f
# 9930  6651837620ee1df904ba7064
#
#                                            textOriginal predicted_label
# 3                                                 andai         negatif
# 37                        di sni seblum game moba entod         negatif
# 50                           kok ga seru tapi gp lanjut         negatif
# 88             jangan bikin tahun nanti isi artis semua         negatif
# 90    yutub rewind gada bang yon mantap jiwa jadi ci...         negatif
# ...                                                 ...             ...
# 9738                               ko edho mana ko edho         negatif
# 9809                            cuma give away ga jelas         negatif
# 9913                  kok kak edhozel ga yah kecewa deh         negatif
# 9925                                       ko edho mana         negatif
# 9930                        edhozel reza ldp mana gk ad         negatif
#
# [257 rows x 3 columns]

# %%
df_netral
# Out:
#                            _id  \
# 0     6651837620ee1df904ba499a
# 2     6651837620ee1df904ba499c
# 5     6651837620ee1df904ba499f
# 6     6651837620ee1df904ba49a0
# 7     6651837620ee1df904ba49a1
# ...                        ...
# 9995  6651837620ee1df904ba70a5
# 9996  6651837620ee1df904ba70a6
# 9997  6651837620ee1df904ba70a7
# 9998  6651837620ee1df904ba70a8
# 9999  6651837620ee1df904ba70a9
#
#                                            textOriginal predicted_label
# 0                            judul lagu menit apa si ka          netral
# 2                             lagu nya apa aja yang tau          netral
# 5                          harus charlie charlie pencil          netral
# 6       sini azka jadi bocah tk sekarang udah besar bgt          netral
# 7                                            lagu detik          netral
# ...                                                 ...             ...
# 9995                                 rachel godard mana          netral
# 9996                                  kangen banget gua          netral
# 9997  kak chandra kak laurentius beatbox nya keren b...          netral
# 9998                                  we mis lord rando          netral
# 9999  anjir jaman jamanya maen warnet ampe gk inget ...          netral
#
# [7842 rows x 3 columns]
