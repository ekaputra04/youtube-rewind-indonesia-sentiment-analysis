# %% [markdown]
# # Visualisasi Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
import seaborn as sns

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = pd.read_csv("../../analysis-data/rewind-2015/analysis_comments.csv")
data
# Out:
#                                                  text analisis_textblob  \
# 0                            mana mbak sasa stepenson            Netral
# 1   bang eka please buatin mixnya lagu bad blod ca...           Positif
# 2                                watch me whip naenae            Netral
# 3                                  10 nama lgunya apa            Netral
# 4                                 aulion paling hebat            Netral
# ..                                                ...               ...
# 95   dlu fun now just giveaway buat indo makin hancur           Positif
# 96                                        awesome col           Positif
# 97  can wait to go to indonesia this country is am...           Positif
# 98                                  ini baik dapat ku           Positif
# 99                         kayak nya kurang duar gitu           Positif
#
#    analisis_naive_bayes
# 0               Positif
# 1               Positif
# 2               Positif
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

def plot_cloud(wordcloud):
  plt.figure(figsize=(10, 8))
  plt.imshow(wordcloud, interpolation="bilinear")
  plt.axis("off")
  plt.show()

all_words = ' '.join([comments for comments in data["text"]])

wordcloud = WordCloud(
  width=3000,
  height=2000,
  random_state=3,
  background_color="black",
  colormap="Blues_r",
  collocations=False,
  stopwords=STOPWORDS
).generate(all_words)

plot_cloud(wordcloud)

# %% [markdown]
# ## Visualisasi Menampilkan Jumlah Sentimen TextBlob

# %%
sns.set_theme()

# Membaca data sentimen dari file CSV
data_sentimen = pd.read_csv("../../analysis-data/rewind-2015/data_sentimen_textblob.csv")

# Menampilkan data_sentimen untuk memastikan telah berhasil dibaca
print(data_sentimen)

# Menyiapkan data untuk plot
labels = ['Positif', 'Negatif', 'Netral']
counts = [data_sentimen["total_positif"].values[0], data_sentimen["total_negatif"].values[0], data_sentimen["total_netral"].values[0]]

def show_bar_chart(labels, counts, title):
    fig, ax = plt.subplots(figsize=(8, 6))
    bars = ax.bar(labels, counts, color=["#2394f7", "#f72323", "#fac343"])

    for bar, count in zip(bars, counts):
        height = bar.get_height()
        ax.annotate(f'{count}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha="center",
                    va="bottom"  # Perbaikan pengejaan
                    )
    ax.grid(axis="y", linestyle="--", alpha=0.7)

    ax.set_xlabel("Sentimen")
    ax.set_ylabel("Jumlah")
    ax.set_title(title)

    plt.show()

# Memanggil fungsi untuk menampilkan grafik batang
show_bar_chart(labels, counts, "Distribusi Sentimen Rewind 2015 Metode Text Blob")
# Out:
#    total_positif  total_netral  total_negatif  total
# 0             40            49             11    100

# %% [markdown]
# ## Visualisasi Menampilkan Jumlah Sentimen Naive Bayes

# %%
sns.set_theme()

# Membaca data sentimen dari file CSV
data_sentimen = pd.read_csv("../../analysis-data/rewind-2015/data_sentimen_naive_bayes.csv")

# Menampilkan data_sentimen untuk memastikan telah berhasil dibaca
print(data_sentimen)

# Menyiapkan data untuk plot
labels = ['Positif', 'Negatif', 'Netral']
counts = [data_sentimen["total_positif"].values[0], data_sentimen["total_negatif"].values[0], data_sentimen["total_netral"].values[0]]

def show_bar_chart(labels, counts, title):
    fig, ax = plt.subplots(figsize=(8, 6))
    bars = ax.bar(labels, counts, color=["#2394f7", "#f72323", "#fac343"])

    for bar, count in zip(bars, counts):
        height = bar.get_height()
        ax.annotate(f'{count}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha="center",
                    va="bottom"  # Perbaikan pengejaan
                    )
    ax.grid(axis="y", linestyle="--", alpha=0.7)

    ax.set_xlabel("Sentimen")
    ax.set_ylabel("Jumlah")
    ax.set_title(title)

    plt.show()

# Memanggil fungsi untuk menampilkan grafik batang
show_bar_chart(labels, counts, "Distribusi Sentimen Rewind 2015 Metode Naive Bayes")
# Out:
#    total_positif  total_netral  total_negatif  total
# 0             75            13             12    100
