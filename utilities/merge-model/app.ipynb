# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
db_name = 'youtube_rewind_indonesia'
collection_label = 'labeling_all_new'

collection_data_training = "data_training_new"
collection_data_testing = "data_testing_new"

load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
client = MongoClient(local_url)
db = client[db_name]
labeling_all_collection = db[collection_label]

labeled_data = list(labeling_all_collection.find())

df = pd.DataFrame(labeled_data)

# %%
# Mengambil masing-masing 1000 data dari setiap kelas untuk data latih
train_df = pd.concat([
    df[df['label'] == 'netral'].sample(n=1000, random_state=42),
    df[df['label'] == 'positif'].sample(n=1000, random_state=42),
    df[df['label'] == 'negatif'].sample(n=1000, random_state=42)
])

# Menggunakan sisa data untuk data uji
remaining_df = df.drop(train_df.index)

# Pastikan sisa data cukup untuk setiap kelas dalam data uji
test_df = remaining_df.groupby('label').apply(lambda x: x.sample(n=1000, random_state=42) if len(x) >= 1000 else x).reset_index(drop=True)

print(f"Data Latih: {len(train_df)}")
print(f"Data Uji: {len(test_df)}")
print("Distribusi label pada data latih:")
print(train_df['label'].value_counts())
print("Distribusi label pada data uji:")
print(test_df['label'].value_counts())
# Out:
# Data Latih: 3000
# Data Uji: 2036
# Distribusi label pada data latih:
# label
# netral     1000
# positif    1000
# negatif    1000
# Name: count, dtype: int64
# Distribusi label pada data uji:
# label
# netral     1000
# positif    1000
# negatif      36
# Name: count, dtype: int64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13980\2293585977.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   test_df = remaining_df.groupby('label').apply(lambda x: x.sample(n=1000, random_state=42) if len(x) >= 1000 else x).reset_index(drop=True)

# %%
train_df
# Out:
#                            _id                 channelId      videoId  \
# 7152  6651a6a8c14ed2b8f4863e50  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 1988  665189f294a2f3e28c752de1  UC-z1ubmS-iHMVr83EEwRS2g  1ZIGLm5cuDo
# 573   6651837620ee1df904ba4c9c  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 4029  6651962182f57e4e5420d7fa  UC-z1ubmS-iHMVr83EEwRS2g  mCyITaDib7M
# 4485  66519bf84bec1f5ab86449db  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# ...                        ...                       ...          ...
# 2901  6651962182f57e4e5420d168  UC-z1ubmS-iHMVr83EEwRS2g  mCyITaDib7M
# 7908  6651a6a8c14ed2b8f4864329  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 2948  6651962182f57e4e5420d1a7  UC-z1ubmS-iHMVr83EEwRS2g  mCyITaDib7M
# 4969  66519bf84bec1f5ab8644cb3  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 1386  6651837620ee1df904ba50e1  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
#
#                                             textDisplay  \
# 7152               GILA KANGEN YOUTUBE ZAMAN VLOGG 🥹🥹🥹🥹
# 1988  Remake Yutub riwain indonesia 2016 Karena tida...
# 573   Bang Eka please buatin Mixnya Lagu Bad Blood c...
# 4029  Yg habis nonton rewind 2020 terus mampir kesin...
# 4485                    I WANNA BACK IN THIS MOMENTTTTT
# ...                                                 ...
# 2901                                No otomotif channel
# 7908                 Kata eriko lim : makan tuh sponsor
# 2948                             Frost diamond mana? :v
# 4969                       Itu yg dislike apa apaan si?
# 1386                         mna kok blom diupload.....
#
#                                            textOriginal   authorDisplayName  \
# 7152                     gila kangen youtube zaman vlog             @mftk23
# 1988        remake yutub riwain indonesia tidak telolet     @mrgeniusly7572
# 573   bang eka please buatin mixnya lagu bad blod ca...         @TakiJoe777
# 4029         yg habis nonton rewind terus mampir kesini         @nazarsatya
# 4485                           wana back in this moment  @thedaydreamer8942
# ...                                                 ...                 ...
# 2901                                 no otomotif chanel    @denmasarief2095
# 7908                   kata eriko lim makan tuh sponsor   @Goodeverything10
# 2948                                 frost diamond mana       @m.majeria590
# 4969                           yang dislike apa apan si      @mataliali8623
# 1386                                  mna blom diupload        @dreamer7622
#
#                                   authorProfileImageUrl  \
# 7152  https://yt3.ggpht.com/ytc/AIdro_mR5fUwI73BLXB8...
# 1988  https://yt3.ggpht.com/ytc/AIdro_mK875UXPoHgVEw...
# 573   https://yt3.ggpht.com/eaVwJuTBBBrvjdmLu7Zx6z-O...
# 4029  https://yt3.ggpht.com/ytc/AIdro_kmoD8Clc92fHi2...
# 4485  https://yt3.ggpht.com/Kdgi3HaNM3EgGVyRf8ZR23-9...
# ...                                                 ...
# 2901  https://yt3.ggpht.com/ytc/AIdro_kNoemjC5cTumF9...
# 7908  https://yt3.ggpht.com/FW0pqzEweTaZJ9iCA84h8pkB...
# 2948  https://yt3.ggpht.com/ytc/AIdro_mWHvKDprgnQiKQ...
# 4969  https://yt3.ggpht.com/ytc/AIdro_nVedfEpqC67hSL...
# 1386  https://yt3.ggpht.com/ytc/AIdro_nL8dQWSWIgVe8l...
#
#                                authorChannelUrl  \
# 7152             http://www.youtube.com/@mftk23
# 1988     http://www.youtube.com/@mrgeniusly7572
# 573          http://www.youtube.com/@TakiJoe777
# 4029         http://www.youtube.com/@nazarsatya
# 4485  http://www.youtube.com/@thedaydreamer8942
# ...                                         ...
# 2901    http://www.youtube.com/@denmasarief2095
# 7908   http://www.youtube.com/@Goodeverything10
# 2948       http://www.youtube.com/@m.majeria590
# 4969      http://www.youtube.com/@mataliali8623
# 1386        http://www.youtube.com/@dreamer7622
#
#                             authorChannelId  canRate viewerRating  likeCount  \
# 7152  {'value': 'UCXuDorrnszDuL995D_J4wIQ'}     True         none          0
# 1988  {'value': 'UCcMgiKgsBIwMbelzlsFdY2g'}     True         none          0
# 573   {'value': 'UC7DhLpCmASltO_UR4nkLpxw'}     True         none          0
# 4029  {'value': 'UCWHI6kbGCtm4GghNclkNDPw'}     True         none          2
# 4485  {'value': 'UCOltYa6odrl7PKdTs0h3XNg'}     True         none          0
# ...                                     ...      ...          ...        ...
# 2901  {'value': 'UCTdtWp2MCT_cM4l7OoAIAAw'}     True         none          0
# 7908  {'value': 'UCxC3DZ6KTqJOaDQPNf2B5vA'}     True         none          0
# 2948  {'value': 'UC-Jlg_cBteGLd9R-SE6eJBQ'}     True         none          1
# 4969  {'value': 'UCanvc-s4bbsD1ZutDEEWj3A'}     True         none          0
# 1386  {'value': 'UCd4AYZRzhGFW-_2lzIY4eUw'}     True         none          0
#
#                publishedAt             updatedAt    label
# 7152  2024-01-13T02:57:29Z  2024-01-13T02:57:29Z   netral
# 1988  2016-12-22T00:07:35Z  2016-12-22T00:07:35Z   netral
# 573   2016-01-27T18:17:53Z  2016-01-27T18:17:53Z   netral
# 4029  2021-01-01T00:52:14Z  2021-01-01T00:52:14Z   netral
# 4485  2023-01-03T12:12:31Z  2023-01-03T12:12:31Z   netral
# ...                    ...                   ...      ...
# 2901  2018-12-15T14:24:22Z  2018-12-15T14:24:22Z  negatif
# 7908  2024-01-13T06:47:03Z  2024-01-13T06:47:03Z  negatif
# 2948  2020-12-08T22:33:12Z  2020-12-08T22:33:12Z  negatif
# 4969  2021-01-07T07:36:02Z  2021-01-07T07:36:02Z  negatif
# 1386  2016-12-18T16:20:53Z  2016-12-18T16:20:53Z  negatif
#
# [3000 rows x 15 columns]

# %%
# Koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name]
collection = db[collection_data_training]

# Konversi DataFrame ke bentuk dictionary
records = train_df.to_dict(orient='records')

# Menyisipkan data ke MongoDB
collection.insert_many(records)

print("Data berhasil diimpor ke MongoDB Local.")
# Out:
# Data berhasil diimpor ke MongoDB Local.

# %%
test_df
# Out:
#                            _id                 channelId      videoId  \
# 0     6651837620ee1df904ba4a33  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 1     6651837620ee1df904ba4b6d  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 2     6651837620ee1df904ba4c35  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 3     6651837620ee1df904ba4ce5  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 4     6651837620ee1df904ba4d1d  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# ...                        ...                       ...          ...
# 2031  6651a129ba72d8bf2eb588a0  UC-z1ubmS-iHMVr83EEwRS2g  IPZO85HFM4w
# 2032  6651a6a8c14ed2b8f486406a  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 2033  6651a6a8c14ed2b8f4863c76  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 2034  66519bf84bec1f5ab8644cab  UC-z1ubmS-iHMVr83EEwRS2g  LhYfsKc0_tA
# 2035  6651a129ba72d8bf2eb58352  UC-z1ubmS-iHMVr83EEwRS2g  IPZO85HFM4w
#
#                                             textDisplay  \
# 0     <a href="https://www.youtube.com/watch?v=fNX6G...
# 1     gua curiga thn ini ga ad Youtube rewind indo 2...
# 2                                          lama juga ya
# 3                       Gema ama bg Tara kgk di ajak :(
# 4                       2017 bikin yang lebih bagus yak
# ...                                                 ...
# 2031                      Lo ga Indo kalo ga nonton ini
# 2032         Kereeeen pake banget..  free Palestine ❤🇵🇸
# 2033          YouTube Rewind mah ga pernah mengecewkan😍
# 2034                                  Gilaa keren batt🥺
# 2035                                         Keren Bett
#
#                                            textOriginal  \
# 0              gw kesini cuma mau liat rich brian doang
# 1     gua curiga thn ga ad youtube rewind indo terla...
# 2                                               lama ya
# 3                             gema ama bg tara kgk ajak
# 4                                 bikin lebih bagus yak
# ...                                                 ...
# 2031                         lo ga indo kalau ga nonton
# 2032                    keren pake banget fre palestine
# 2033           youtube rewind mah ga pernah mengecewkan
# 2034                                     gila keren bat
# 2035                                          keren bet
#
#                     authorDisplayName  \
# 0                    @irengguseng7486
# 1                          @mraio7379
# 2       @fahrulhabibazlipanjaitan2505
# 3                  @dinosauraawr_5305
# 4                            @zxkevnn
# ...                               ...
# 2031                  @mayninanik6715
# 2032                     @abysfyz3887
# 2033  @ArchellioElZaidanSetiawa-cf4sc
# 2034                 @dibah_ohaja7557
# 2035               @alexanderizzi4775
#
#                                   authorProfileImageUrl  \
# 0     https://yt3.ggpht.com/ytc/AIdro_kNs9UjFnsi8vp9...
# 1     https://yt3.ggpht.com/ytc/AIdro_mblII19Hom7VSQ...
# 2     https://yt3.ggpht.com/ytc/AIdro_kA1umENclzF85F...
# 3     https://yt3.ggpht.com/ytc/AIdro_m0cjXpx2BlFgKr...
# 4     https://yt3.ggpht.com/nGDpe2yGsgYRZXdqJKc3arJM...
# ...                                                 ...
# 2031  https://yt3.ggpht.com/ytc/AIdro_mHmuU06D7d5sBR...
# 2032  https://yt3.ggpht.com/L7xoAbFKFJcPZlcUr-XTl4qL...
# 2033  https://yt3.ggpht.com/ytc/AIdro_nmtsXDHjV3vsi3...
# 2034  https://yt3.ggpht.com/wkfNfv9uYf7cGKrpYNtKNvMH...
# 2035  https://yt3.ggpht.com/ytc/AIdro_lkS5ZDqimTYp26...
#
#                                        authorChannelUrl  \
# 0               http://www.youtube.com/@irengguseng7486
# 1                     http://www.youtube.com/@mraio7379
# 2     http://www.youtube.com/@fahrulhabibazlipanjait...
# 3             http://www.youtube.com/@dinosauraawr_5305
# 4                       http://www.youtube.com/@zxkevnn
# ...                                                 ...
# 2031             http://www.youtube.com/@mayninanik6715
# 2032                http://www.youtube.com/@abysfyz3887
# 2033  http://www.youtube.com/@ArchellioElZaidanSetia...
# 2034            http://www.youtube.com/@dibah_ohaja7557
# 2035          http://www.youtube.com/@alexanderizzi4775
#
#                             authorChannelId  canRate viewerRating  likeCount  \
# 0     {'value': 'UCc_Fx04zB9rxwUfDBPDAS9Q'}     True         none          0
# 1     {'value': 'UCUqZ7oyXXSugw-cAMJG_vew'}     True         none          0
# 2     {'value': 'UChUz_nTSoFw6u748uNV3Kkg'}     True         none          0
# 3     {'value': 'UC06DacX4CaCjwT79ukrifow'}     True         none          0
# 4     {'value': 'UC-pyrWmDOuLqN-4IGe9rijA'}     True         none          0
# ...                                     ...      ...          ...        ...
# 2031  {'value': 'UCec5x9gLP_IpK0Kcj2o4pwA'}     True         none          0
# 2032  {'value': 'UCCiiZ4cb8aWBKUNEl6DXsYg'}     True         none          0
# 2033  {'value': 'UCnd_Rh1_EjveSRkesW5WH-g'}     True         none          0
# 2034  {'value': 'UCFWQDTosVYB3sSYcNWDiagg'}     True         none          0
# 2035  {'value': 'UCAiwJN2lGibbaAyoGPyA3FQ'}     True         none          0
#
#                publishedAt             updatedAt    label
# 0     2018-11-18T07:19:03Z  2018-11-18T07:19:03Z  negatif
# 1     2016-12-09T18:37:53Z  2016-12-09T18:37:53Z  negatif
# 2     2016-12-18T12:16:16Z  2016-12-18T12:16:16Z  negatif
# 3     2016-06-10T23:11:54Z  2016-06-10T23:11:54Z  negatif
# 4     2017-05-14T14:55:37Z  2017-05-14T14:55:37Z  negatif
# ...                    ...                   ...      ...
# 2031  2021-12-31T23:02:48Z  2021-12-31T23:02:48Z  positif
# 2032  2024-01-14T10:03:12Z  2024-01-14T10:03:12Z  positif
# 2033  2024-01-15T07:32:29Z  2024-01-15T07:32:29Z  positif
# 2034  2021-01-13T03:01:08Z  2021-01-13T03:01:08Z  positif
# 2035  2022-01-08T04:22:21Z  2022-01-08T04:22:21Z  positif
#
# [2036 rows x 15 columns]

# %%
# Koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name]
collection = db[collection_data_testing]

# Konversi DataFrame ke bentuk dictionary
records = test_df.to_dict(orient='records')

# Menyisipkan data ke MongoDB
collection.insert_many(records)

print("Data berhasil diimpor ke MongoDB Local.")
# Out:
# Data berhasil diimpor ke MongoDB Local.
