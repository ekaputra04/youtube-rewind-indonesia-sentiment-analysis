# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
# collection_name = 'full_labeling_all'
collection_name = 'labeling_all'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
# label_counts = df_labeled['predicted_label'].value_counts()
label_counts = df_labeled['label'].value_counts()
label_counts
# Out:
# label
# netral     5661
# positif    4783
# negatif    1557
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 4783
# Jumlah komentar negatif: 1557
# Jumlah komentar netral: 5661

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
# df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
# df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
# df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

df_positif = df_labeled[df_labeled['label'] == 'positif']
df_negatif = df_labeled[df_labeled['label'] == 'negatif']
df_netral = df_labeled[df_labeled['label'] == 'netral']

# %%
df_positif
# Out:
#                             _id  \
# 1      6651837620ee1df904ba499b
# 4      6651837620ee1df904ba499e
# 10     6651837620ee1df904ba49a4
# 11     6651837620ee1df904ba49a5
# 12     6651837620ee1df904ba49a6
# ...                         ...
# 11986  6651a6a8c14ed2b8f4864425
# 11989  6651a6a8c14ed2b8f4864428
# 11991  6651a6a8c14ed2b8f486442a
# 11996  6651a6a8c14ed2b8f486442f
# 11998  6651a6a8c14ed2b8f4864431
#
#                                             textOriginal    label      videoId
# 1                           rewind ter the best sih nice  positif  fNX6Gu2F7A8
# 4                  anjir keren gilak youtubers indonesia  positif  fNX6Gu2F7A8
# 10                          wow seru banget video kompak  positif  fNX6Gu2F7A8
# 11     am only one who always watching this video al ...  positif  fNX6Gu2F7A8
# 12                  wow kerensnjshshsjsh aku suka banget  positif  fNX6Gu2F7A8
# ...                                                  ...      ...          ...
# 11986                                      merinding pol  positif  Q5vQawTFJ0I
# 11989                                   keren bngt pecah  positif  Q5vQawTFJ0I
# 11991                keren banget banget congrats for al  positif  Q5vQawTFJ0I
# 11996                                       keren banget  positif  Q5vQawTFJ0I
# 11998                                         thanks man  positif  Q5vQawTFJ0I
#
# [4783 rows x 4 columns]

# %%
df_negatif
# Out:
#                             _id  \
# 3      6651837620ee1df904ba499d
# 8      6651837620ee1df904ba49a2
# 18     6651837620ee1df904ba49ac
# 19     6651837620ee1df904ba49ad
# 27     6651837620ee1df904ba49b5
# ...                         ...
# 11952  6651a6a8c14ed2b8f4864403
# 11979  6651a6a8c14ed2b8f486441e
# 11992  6651a6a8c14ed2b8f486442b
# 11995  6651a6a8c14ed2b8f486442e
# 11999  6651a6a8c14ed2b8f4864432
#
#                                             textOriginal    label      videoId
# 3                                                  andai  negatif  fNX6Gu2F7A8
# 8                                     yang punya lagu gk  negatif  fNX6Gu2F7A8
# 18     nonton di bulan november mana nie gimana yak f...  negatif  fNX6Gu2F7A8
# 19                                 baju pink mana anying  negatif  fNX6Gu2F7A8
# 27                 tetap bikin merinding keren salam dri  negatif  fNX6Gu2F7A8
# ...                                                  ...      ...          ...
# 11952                          hm yang kasih dislike wth  negatif  Q5vQawTFJ0I
# 11979                       bagus daripada tiktok replay  negatif  Q5vQawTFJ0I
# 11992    hoto dlu ngemis ga hoto ga kasih eh kemarin isu  negatif  Q5vQawTFJ0I
# 11995                    keren lebih bagus sih dri belah  negatif  Q5vQawTFJ0I
# 11999                                          anj jelek  negatif  Q5vQawTFJ0I
#
# [1557 rows x 4 columns]

# %%
df_netral
# Out:
#                             _id  \
# 0      6651837620ee1df904ba499a
# 2      6651837620ee1df904ba499c
# 5      6651837620ee1df904ba499f
# 6      6651837620ee1df904ba49a0
# 7      6651837620ee1df904ba49a1
# ...                         ...
# 11990  6651a6a8c14ed2b8f4864429
# 11993  6651a6a8c14ed2b8f486442c
# 11994  6651a6a8c14ed2b8f486442d
# 11997  6651a6a8c14ed2b8f4864430
# 12000  6651a6a8c14ed2b8f4864433
#
#                                           textOriginal   label      videoId
# 0                           judul lagu menit apa si ka  netral  fNX6Gu2F7A8
# 2                            lagu nya apa aja yang tau  netral  fNX6Gu2F7A8
# 5                         harus charlie charlie pencil  netral  fNX6Gu2F7A8
# 6      sini azka jadi bocah tk sekarang udah besar bgt  netral  fNX6Gu2F7A8
# 7                                           lagu detik  netral  fNX6Gu2F7A8
# ...                                                ...     ...          ...
# 11990                                              apa  netral  Q5vQawTFJ0I
# 11993                     makas udah suport chanel gue  netral  Q5vQawTFJ0I
# 11994                      gila merinding keren banget  netral  Q5vQawTFJ0I
# 11997       gemetar gua ntonya coy kelas banget mantap  netral  Q5vQawTFJ0I
# 12000                          gue nang nontonya keren  netral  Q5vQawTFJ0I
#
# [5661 rows x 4 columns]
