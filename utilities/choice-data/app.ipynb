# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
# collection_name = 'full_labeling_all'
collection_name = 'labeling_all_new'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
# label_counts = df_labeled['predicted_label'].value_counts()
label_counts = df_labeled['label'].value_counts()
label_counts
# Out:
# label
# netral     3745
# positif    3280
# negatif    1036
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 3280
# Jumlah komentar negatif: 1036
# Jumlah komentar netral: 3745

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
# df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
# df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
# df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

df_positif = df_labeled[df_labeled['label'] == 'positif']
df_negatif = df_labeled[df_labeled['label'] == 'negatif']
df_netral = df_labeled[df_labeled['label'] == 'netral']

# %%
df_positif
# Out:
#                            _id                 channelId      videoId  \
# 1     6651837620ee1df904ba499b  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 4     6651837620ee1df904ba499e  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 8     6651837620ee1df904ba49a4  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 9     6651837620ee1df904ba49a5  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 10    6651837620ee1df904ba49a6  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# ...                        ...                       ...          ...
# 8052  6651a6a8c14ed2b8f4864425  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8054  6651a6a8c14ed2b8f4864428  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8056  6651a6a8c14ed2b8f486442a  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8058  6651a6a8c14ed2b8f486442f  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8059  6651a6a8c14ed2b8f4864431  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
#
#                                             textDisplay  \
# 1                     Rewind ter the best ini sih, nice
# ...

# %%
df_negatif
# Out:
#                            _id                 channelId      videoId  \
# 3     6651837620ee1df904ba499d  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 15    6651837620ee1df904ba49ad  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 23    6651837620ee1df904ba49b5  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 24    6651837620ee1df904ba49b6  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 26    6651837620ee1df904ba49b8  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# ...                        ...                       ...          ...
# 7975  6651a6a8c14ed2b8f486439e  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 7992  6651a6a8c14ed2b8f48643b8  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8033  6651a6a8c14ed2b8f4864403  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8049  6651a6a8c14ed2b8f486441e  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8060  6651a6a8c14ed2b8f4864432  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
#
#                                             textDisplay  \
# 3                                              Andai...
# ...

# %%
df_netral
# Out:
#                            _id                 channelId      videoId  \
# 0     6651837620ee1df904ba499a  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 2     6651837620ee1df904ba499c  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 5     6651837620ee1df904ba49a0  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 6     6651837620ee1df904ba49a1  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# 7     6651837620ee1df904ba49a3  UC-z1ubmS-iHMVr83EEwRS2g  fNX6Gu2F7A8
# ...                        ...                       ...          ...
# 8050  6651a6a8c14ed2b8f4864423  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8051  6651a6a8c14ed2b8f4864424  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8053  6651a6a8c14ed2b8f4864426  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8055  6651a6a8c14ed2b8f4864429  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
# 8057  6651a6a8c14ed2b8f486442d  UC-z1ubmS-iHMVr83EEwRS2g  Q5vQawTFJ0I
#
#                                             textDisplay  \
# 0                  judul lagu di menit 01.14 apa si ka?
# ...
