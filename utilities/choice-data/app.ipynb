# %%
import pandas as pd
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
# Nama database dan collection
db_name = 'youtube_rewind_indonesia'
collection_name = 'full_labeling_all'
# collection_name = 'labeling_all'

# Memuat value dari file .env
load_dotenv()

mongodb_url = os.getenv('URL_SANDY')
local_url = os.getenv('URL_LOCAL')

# %%
# Membuat koneksi ke MongoDB
client = MongoClient(local_url)
db = client[db_name] 
full_labeling_collection = db[collection_name]

# %%
labeled_data = list(full_labeling_collection.find())
df_labeled = pd.DataFrame(labeled_data)

# %%
# Menghitung jumlah setiap label
label_counts = df_labeled['predicted_label'].value_counts()
# label_counts = df_labeled['label'].value_counts()
label_counts
# Out:
# predicted_label
# positif    26462
# netral     17573
# negatif    15965
# Name: count, dtype: int64

# %%
# Menyimpan jumlah ke dalam variabel
positif_count = label_counts.get('positif', 0)
negatif_count = label_counts.get('negatif', 0)
netral_count = label_counts.get('netral', 0)

# Menampilkan hasil
print(f"Jumlah komentar positif: {positif_count}")
print(f"Jumlah komentar negatif: {negatif_count}")
print(f"Jumlah komentar netral: {netral_count}")
# Out:
# Jumlah komentar positif: 26462
# Jumlah komentar negatif: 15965
# Jumlah komentar netral: 17573

# %%
# Membagi dataframe menjadi tiga berdasarkan nilai dari kolom 'predicted_label'
df_positif = df_labeled[df_labeled['predicted_label'] == 'positif']
df_negatif = df_labeled[df_labeled['predicted_label'] == 'negatif']
df_netral = df_labeled[df_labeled['predicted_label'] == 'netral']

# df_positif = df_labeled[df_labeled['label'] == 'positif']
# df_negatif = df_labeled[df_labeled['label'] == 'negatif']
# df_netral = df_labeled[df_labeled['label'] == 'netral']

# %%
df_positif
# Out:
#                             _id  \
# 1      6651837620ee1df904ba499b
# 4      6651837620ee1df904ba499e
# 10     6651837620ee1df904ba49a4
# 12     6651837620ee1df904ba49a6
# 14     6651837620ee1df904ba49a8
# ...                         ...
# 59995  6651a6a8c14ed2b8f486636f
# 59996  6651a6a8c14ed2b8f4866370
# 59997  6651a6a8c14ed2b8f4866371
# 59998  6651a6a8c14ed2b8f4866372
# 59999  6651a6a8c14ed2b8f4866373
#
#                                             textOriginal      videoId  \
# 1                           rewind ter the best sih nice  fNX6Gu2F7A8
# 4                  anjir keren gilak youtubers indonesia  fNX6Gu2F7A8
# 10                          wow seru banget video kompak  fNX6Gu2F7A8
# 12                  wow kerensnjshshsjsh aku suka banget  fNX6Gu2F7A8
# 14                       love this rewind nice work guys  fNX6Gu2F7A8
# ...                                                  ...          ...
# 59995                    jujur yang paling bkin gua haru  Q5vQawTFJ0I
# 59996                                       mantap keren  Q5vQawTFJ0I
# 59997                                              keren  Q5vQawTFJ0I
# 59998  moga video tragedi gunung marapi sumatra barat...  Q5vQawTFJ0I
# 59999                                       keren banget  Q5vQawTFJ0I
#
#       predicted_label
# 1             positif
# 4             positif
# 10            positif
# 12            positif
# 14            positif
# ...               ...
# 59995         positif
# 59996         positif
# 59997         positif
# 59998         positif
# 59999         positif
#
# [26462 rows x 4 columns]

# %%
df_negatif
# Out:
#                             _id  \
# 3      6651837620ee1df904ba499d
# 5      6651837620ee1df904ba499f
# 6      6651837620ee1df904ba49a0
# 20     6651837620ee1df904ba49ae
# 28     6651837620ee1df904ba49b6
# ...                         ...
# 59958  6651a6a8c14ed2b8f486634a
# 59959  6651a6a8c14ed2b8f486634b
# 59970  6651a6a8c14ed2b8f4866356
# 59972  6651a6a8c14ed2b8f4866358
# 59987  6651a6a8c14ed2b8f4866367
#
#                                             textOriginal      videoId  \
# 3                                                  andai  fNX6Gu2F7A8
# 5                           harus charlie charlie pencil  fNX6Gu2F7A8
# 6        sini azka jadi bocah tk sekarang udah besar bgt  fNX6Gu2F7A8
# 20                                  udah nonton ga bosen  fNX6Gu2F7A8
# 28     tambahin artis dong sama youtubers kan seru al...  fNX6Gu2F7A8
# ...                                                  ...          ...
# 59958  bagus ga isi anak game semua kek rewind taun k...  Q5vQawTFJ0I
# 59959       keren aku suka sekali isi banyak goreng haha  Q5vQawTFJ0I
# 59970                            meanwhile rewind tiktok  Q5vQawTFJ0I
# 59972  kayak yang kurang deh sisi horor mana kayak dm...  Q5vQawTFJ0I
# 59987                                      rewind circle  Q5vQawTFJ0I
#
#       predicted_label
# 3             negatif
# 5             negatif
# 6             negatif
# 20            negatif
# 28            negatif
# ...               ...
# 59958         negatif
# 59959         negatif
# 59970         negatif
# 59972         negatif
# 59987         negatif
#
# [15965 rows x 4 columns]

# %%
df_netral
# Out:
#                             _id  \
# 0      6651837620ee1df904ba499a
# 2      6651837620ee1df904ba499c
# 7      6651837620ee1df904ba49a1
# 8      6651837620ee1df904ba49a2
# 9      6651837620ee1df904ba49a3
# ...                         ...
# 59977  6651a6a8c14ed2b8f486635d
# 59980  6651a6a8c14ed2b8f4866360
# 59983  6651a6a8c14ed2b8f4866363
# 59986  6651a6a8c14ed2b8f4866366
# 59992  6651a6a8c14ed2b8f486636c
#
#                                             textOriginal      videoId  \
# 0                             judul lagu menit apa si ka  fNX6Gu2F7A8
# 2                              lagu nya apa aja yang tau  fNX6Gu2F7A8
# 7                                             lagu detik  fNX6Gu2F7A8
# 8                                     yang punya lagu gk  fNX6Gu2F7A8
# 9      nungu youtube rewind pas nonton baru nyadar ka...  fNX6Gu2F7A8
# ...                                                  ...          ...
# 59977                                   kembali xyloband  Q5vQawTFJ0I
# 59980  tiap taun ntn youtube rewind kaca kaca trs mat...  Q5vQawTFJ0I
# 59983                                        ria sw dong  Q5vQawTFJ0I
# 59986                 haru banget nyata secepet yah lalu  Q5vQawTFJ0I
# 59992                                        bryan furan  Q5vQawTFJ0I
#
#       predicted_label
# 0              netral
# 2              netral
# 7              netral
# 8              netral
# 9              netral
# ...               ...
# 59977          netral
# 59980          netral
# 59983          netral
# 59986          netral
# 59992          netral
#
# [17573 rows x 4 columns]
